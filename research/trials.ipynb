# %%
import os

# %%
# %pwd
# Out:
# '/Users/bhikipallai/Desktop/Projects/Chicken_fecal/research'

# %%
os.chdir('../.')

# %%
# %pwd
# Out:
# '/Users/bhikipallai/Desktop/Projects/Chicken_fecal'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf

# %%
url = 'https://drive.google.com/file/d/1BoMmXX1A0bc-inv1QK19Ci6L-r96iXjv/view?usp=drive_link'

# %%
url.split('/')
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1BoMmXX1A0bc-inv1QK19Ci6L-r96iXjv',
#  'view?usp=drive_link']

# %%
id = url.split('/')[-2]

# %%
id
# Out:
# '1BoMmXX1A0bc-inv1QK19Ci6L-r96iXjv'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='

# %%
import gdown

# %%
dnld = gdown.download(prefix+id)
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1BoMmXX1A0bc-inv1QK19Ci6L-r96iXjv
# To: /Users/bhikipallai/Desktop/Projects/Chicken_fecal/Chicken-fecal-images.zip
# 100%|██████████| 11.6M/11.6M [00:01<00:00, 8.39MB/s]

# %%
import cv2

# %%
import matplotlib.pyplot as plt
img = cv2.imread('/Users/bhikipallai/Desktop/Projects/Chicken_fecal/data/data_splitting/test/Coccidiosis/cocci.4.jpg')
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
import glob

# %%
glob.glob('/Users/bhikipallai/Desktop/Projects/Chicken_fecal/data/data_splitting/test/*')
# Out:
# ['/Users/bhikipallai/Desktop/Projects/Chicken_fecal/data/data_splitting/test/Coccidiosis',
#  '/Users/bhikipallai/Desktop/Projects/Chicken_fecal/data/data_splitting/test/Healthy']
